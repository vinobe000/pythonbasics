# %%
weight_in_kg=int(input("enter the weight"))
height_in_meters=float(input("enter the height"))
bmi=weight_in_kg/(height_in_meters*height_in_meters)
print(bmi)
print("bmi is safe ")
# Out:
# enter the weight70
# enter the height1.68
# 24.801587301587304
# bmi is safe

# %%
#celcius to fahrnheit conversions
cels=float(input("enter the degree"))
fahr=cels*9/5+32
print(fahr)
# Out:
# enter the degree40
# 104.0

# %%
#fahrenheit to celcius conversion
fahr=float(input("enter the temperature"))
cels=(fahr-32)/1.8
print(cels)
# Out:
# enter the temperature104.0
# 40.0

# %%
name="vinoth"
age=28
print(name,"you are",age,"now but")
# Out:
# vinoth you are 28 now but

# %%
name="vinoth"
age=28
print(name,"you are ",age,"now but",end="")
print("you will be ",age+1,"next year")
# Out:
# vinoth you are  28 now butyou will be  29 next year
